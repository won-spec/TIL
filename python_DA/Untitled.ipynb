# %%
import numpy as np
import pandas as pd
df_movie = pd.read_csv("./data/movies.csv")
df_rating = pd.read_csv("./data/ratings.csv")
# df.columns.values[0] = "Index"
# display(df.head(10))
# df.drop("Index",axis=1, inplace=True)
# df
# display(df_rating)
# display(df_movie)

df3=pd.merge(df_movie,df_rating, on = "movieId", how="left")
df3
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100849   193581  Black Butler: Book of the Atlantic (2017)
# 100850   193583               No Game No Life: Zero (2017)
# 100851   193585                               Flint (2017)
# 100852   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100853   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy     1.0     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy     5.0     4.0
# ...

# %%
df3["rating"].mean()
# Out:
# 3.501556983616962

# %%
df3["rating"].groupby(df3["userId"]).mean()
# Out:
# userId
# 1.0      4.366379
# 2.0      3.948276
# 3.0      2.435897
# 4.0      3.555556
# 5.0      3.636364
#            ...
# 606.0    3.657399
# 607.0    3.786096
# 608.0    3.134176
# 609.0    3.270270
# 610.0    3.688556
# Name: rating, Length: 610, dtype: float64
